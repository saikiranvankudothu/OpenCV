# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\saiki\anaconda3\envs\opencv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\saiki\anaconda3\envs\opencv\lib\site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
image = cv2.imread("./img1.png")

# %%
if image is None:
    print("error : cound not load the image")

else:
    print("image loaded successfully")
# Out:
# image loaded successfully

# %%
cv2.imshow("Image window",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# write the image
image_new = image+100
cv2.imwrite("./output.png",image_new)
# Out:
# True

# %%
image2 = cv2.imread("./output.png")

# %%
cv2.imshow("the output image",image2)
cv2.waitKey(0)
cv2.destroyAllWindows()
